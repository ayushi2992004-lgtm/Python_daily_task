# %%
# 1. Comments & Print
# a) Single line comment
print("Name: Ayushi Gajbhiye")

# b) Multi-line comment (using #)
print("College: Priyadarshini J.L. College of Engineering")
print("Course: Full Stack Data Science with Gen AI")

# c) Docstring
"""
This is a docstring.
It can be used to discribe the program
"""
# Out:
# Name: Ayushi Gajbhiye
# College: Priyadarshini J.L. College of Engineering
# Course: Full Stack Data Science with Gen AI
# '\nThis is a docstring.\nIt can be used to discribe the program\n'

# %%
# 2. Indentation Practice
if True:
    print("Hello World")
    print("Welcome to Python")
# Out:
# Hello World
# Welcome to Python

# %%
# 3. Variables Declaration
name = "Ayushi"
age = 21
height = 4.9
is_student = True
print(name, type(name))
print(age, type(age))
print(height, type(height))
print(is_student, type(is_student))
# Out:
# Ayushi <class 'str'>
# 21 <class 'int'>
# 4.9 <class 'float'>
# True <class 'bool'>

# %%
# 4. Variable Naming Rules
MyVar
_score

# %%
# 5. Arithmetic Operators
a = int(input("Enter First Number: "))
b = int(input("Enter Second Number: "))
print("Sum = ", a+b)
print("Difference= ", a-b)
print("Product = ", a*b)
print("Division = ", a/b)
print("Module = ", a%b)
print("Power = ", a**b)
# Out:
# Enter First Number:  10
# Enter Second Number:  3
# Sum =  13
# Difference=  7
# Product =  30
# Division =  3.3333333333333335
# Module =  1
# Power =  1000

# %%
# 6. Comparison Operators
a = int(input("Enter First Number: "))
b = int(input("Enter Second Number: "))
print(a == b)
print(a != b)
print(a > b)
print(a < b)
print(a >= b)
print(a <= b)
# Out:
# Enter First Number:  10
# Enter Second Number:  20
# False
# True
# False
# True
# False
# True

# %%
# 7. Assignment Operators
a = 10
a += 5
print(a)

a -= 3
print(a)

a *= 2 
print(a)

a /= 4
print(a)

a //= 2
print(a)

a %= 3
print(a)

a **= 2
print(a)
# Out:
# 15
# 12
# 24
# 6.0
# 3.0
# 0.0
# 0.0

# %%
# 8. Local vs Global Variable
college = "Priyadarshini J.L. College of Engineering"
def show():
    global college
    department = "Computer Science"
    print("College: ", college)
    print("Department: ", department)
show()
print("Outside Function: ", college)
# Out:
# College:  Priyadarshini J.L. College of Engineering
# Department:  Computer Science
# Outside Function:  Priyadarshini J.L. College of Engineering

# %%
# 9. Simple Calculator
num1 = float(input("Enter First Number: "))
num2 = float(input("Enter Second Number: "))
op = input("Enter Operator (+, -, *, /, //, %, **): ")
if op == "+":
    print("Result = ", num1 + num2)
elif op == "-":
    print("Result = ", num1 - num2)
elif op == "*":
    print("Result = ", num1 * num2)
elif op == "/":
    print("Result = ", num1 / num2)
elif op == "//":
    print("Result = ", num1 // num2)
elif op == "%":
    print("Result = ", num1 % num2)
elif op == "**":
    print("Result = ", num1 ** num2)
else:
    print("Invalid Opeartor")
# Out:
# Enter First Number:  10
# Enter Second Number:  5
# Enter Operator (+, -, *, /, //, %, **):  //
# Result =  2.0

# %%
# 10. Temperature Converter
choice = input("Convert(C/F): ").upper()
if choice == "C":
    c = float(input("Enter Celsius: "))
    f = (c * 9/5)+32
    print("Fahrenheit = ", f)
elif choice == "F":
    f = float(input("Enter Fahrenheit: "))
    c = (f-32)*5/9
    print("Celsius = ", c)
else:
    print("Invalid Choice")
# Out:
# Convert(C/F):  c
# Enter Celsius:  37
# Fahrenheit =  98.6

# %%
# 11. Area and Perimeter Calculator
radius = float(input("Enter Radius = "))
pi = 3.14
area = pi*radius**2
circumference = 2* pi * radius
print("Area = ", area)
print("Circumference = ", circumference)
# Out:
# Enter Radius =  7
# Area =  153.86
# Circumference =  43.96

# %%
# 12. Student Grade Calculator
m1 = int(input("English: "))
m2 = int(input("Math: "))
m3 = int(input("Science: "))
m4 = int(input("Computer: "))
m5 = int(input("Hindi: "))
total = m1+m2+m3+m4+m5
percentage = total/5
print("Percentage: ", percentage)
if percentage >= 90:
    print("Grade A++")
elif percentage >= 80:
    print("Grade A")
elif percentage >= 70:
    print("Grade B")
elif percentage >=60:
    print("Grade C")
else:
    print("Fails")
# Out:
# English:  85
# Math:  90
# Science:  80
# Computer:  95
# Hindi:  90
# Percentage:  88.0
# Grade A

# %%
# 13. Swap Two Variables
# a) Third variable
a = int(input("Enter First Number: "))
b = int(input("Enter Second Number: "))
temp = a
a = b
b = temp
print("After Swapping: ")
print("a = ", a)
print("b = ", b)
# Out:
# Enter First Number:  10
# Enter Second Number:  20
# After Swapping:
# a =  20
# b =  10

# %%
# b) Without third variable (Python way)
a = int(input("Enter First Number: "))
b = int(input("Enter Second Number: "))
a, b=b,a
print("a = ", a)
print("b = ", b)
# Out:
# Enter First Number:  15
# Enter Second Number:  30
# a =  30
# b =  15

# %%
# 14. Loan Eligibility
age = int(input("Enter Age: "))
salary = int(input("Enter Salary: "))
if age >= 18 and age <= 60 and salary >25000:
    print("Eligible for Loan")
else:
    print("Not Eligible")
# Out:
# Enter Age:  30
# Enter Salary:  50000
# Eligible for Loan

# %%
# 15. Dynamic Typing Demo
x = 10
print(x, type(x))

x = "Python"
print(x, type(x))

x = 10.5
print(x, type(x))

x = True
print(x, type(x))
# Out:
# 10 <class 'int'>
# Python <class 'str'>
# 10.5 <class 'float'>
# True <class 'bool'>
