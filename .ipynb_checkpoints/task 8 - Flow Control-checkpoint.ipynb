# %% [markdown]
# # Part-1

# %%
#1 Check positive or negative
num = int(input("Enter a number: "))
if num>=0:
    print("Positive")
else:
    print("Negative")
# Out:
# Enter a number:  -2
# Negative

# %%
#2 Check voting Eligibility
age = int(input("Enter age: "))
if age>=18:
    print("You can vote")
# Out:
# Enter age:  12

# %%
#3 Print Larger number
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
if a>b:
    print(a)
else:
    print(b)
# Out:
# Enter first number:  25
# Enter second number:  36
# 36

# %%
#4 Check Even or Odd
num = int(input("Enter a number: "))
if num%2==0:
    print("Even Number")
else:
    print("Odd Number")
# Out:
# Enter a number:  3
# Odd Number

# %%
#5 Check character is A or not
character = input("Enter a Character: ")
if character=="A":
    print("It is A")
else:
    print("It is not A")
# Out:
# Enter a Character:  A
# It is A

# %%
#6 Pass or Fail
marks = int(input("Enter marks: "))
if marks>=40:
    print("Pass")
else:
    print("Fail")
# Out:
# Enter marks:  30
# Fail

# %%
#7 Divisible by 5
num = int(input("Enter a Number: "))
if num%5==0:
    print("Divisible by 5")
else:
    print("Not Divisible")
# Out:
# Enter a Number:  55
# Divisible by 5

# %%
#8 positive, negative or zero
num = int(input("Enter a Number: "))
if num>0:
    print("Positive")
elif num<0:
    print("Negative")
else:
    print("Zero")
# Out:
# Enter a Number:  0
# Zero

# %%
#9 Largest of three number
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))
if a>=b and a>=c:
    print(a)
elif b>=a and b>=c:
    print(b)
else:
    print(c)
# Out:
# Enter first number:  2
# Enter second number:  7
# Enter third number:  3
# 7

# %%
#10 Leap year
year = int(input("Enter Year: "))
if (year%4==0 and year%100!=0) or (year%400==0):
    print("Leap Year")
else:
    print("Not a Leap Year")
# Out:
# Enter Year:  2020
# Leap Year

# %%
#11 Vowel or Constant
character = input("Enter a Character: ")
if character.lower() in "aeiou":
    print("Vowel")
else:
    print("Consonant")
# Out:
# Enter a Character:  j
# Consonant

# %%
#12 Salary category
salary = int(input("Enter salary: "))
if salary>50000:
    print("High")
elif salary>30000:
    print("Medium")
else:
    print("Low")
# Out:
# Enter salary:  80000
# High

# %%
#13 Temperature Category
temp = int(input("Enter Temperature: "))
if temp>30:
    print("Hot")
elif temp>=20:
    print("Warm")
else:
    print("Cold")
# Out:
# Enter Temperature:  45
# Hot

# %%
#14 Login check
username = input("Enter username: ")
password = input("Enter password: ")
if username == "admin" and password == "1234":
    print("Login Successful")
else:
    print("Login Failed")
# Out:
# Enter username:  admin
# Enter password:  1234
# Login Successful

# %%
#15 Triangle type
a = int(input("Enter side 1: "))
b = int(input("Enter side 2: "))
c = int(input("Enter side 3: "))
if a+b>c and a+c>b and c+b>a:
    print("Valied Triangle")
    if a==b==c:
        print("Equilateral Triangle")
    elif a==b or b==c or a==c:
        print("Isosceles")
    else:
        print("Scalene")
else:
    print("Invalied Triangle")
# Out:
# Enter side 1:  5
# Enter side 2:  5
# Enter side 3:  5
# Valied Triangle
# Equilateral Triangle

# %%
# 16 percentage and Grade
m1 = int(input("Enter mark 1: "))
m2 = int(input("Enter mark 2: "))
m3 = int(input("Enter mark 3: "))
m4 = int(input("Enter mark 4: "))
m5 = int(input("Enter mark 5: "))
total = m1+m2+m3+m4+m5
per = total/5
print("Percentage = ",per)
if per>=90:
    print("A+")
elif per>=80:
    print("A")
elif per>=70:
    print("B")
elif per>=60:
    print("C")
else:
    print("Fail")
# Out:
# Enter mark 1:  92
# Enter mark 2:  88
# Enter mark 3:  79
# Enter mark 4:  56
# Enter mark 5:  80
# Percentage =  79.0
# B

# %%
# 17 FizzBuzz
num = int(input("Enter a nummber: "))
if num%3==0 and num%5==0:
    print("FizzBuzz")
elif num%3==0:
    print("Fizz")
elif num%5==0:
    print("Buzz")
else:
    print(num)
# Out:
# Enter a nummber:  15
# FizzBuzz

# %%
#18 Army elibigility
age = int(input("Enter Age: "))
gender = input("Enter Gender: ")
if age>=18 and gender.lower()=="male":
    print("Eligible for Army")
elif age>=18 and gender.lower()=="female":
    print("Eligible for Other Services")
else:
    print("Not Eligible")
# Out:
# Enter Age:  19
# Enter Gender:  male
# Eligible for Army

# %%
#19 Character type
character = input("Enter a Character: ")
if character.isupper():
    print("Uppercase")
elif character.islower():
    print("Lowercase")
elif character.isdigit():
    print("Digit")
else:
    print("Special Character")
# Out:
# Enter a Character:  @
# Special Character

# %%
# print number in ascending order(Without sort)
a = int(input("Enter first Number: "))
b = int(input("Enter second Number: "))
c = int(input("Enter third Number: ")) 
if a<=b and a<=c:
    if b<=c:
        print(a,b,c)
    else:
        print(a,c,b)
elif b<=a and b<=c:
    if a<=c:
        print(b,a,c)
    else:
        print(b,c,a)
else:
    if a<=b:
        print(c,a,b)
    else:
        print(c,b,a)
# Out:
# Enter first Number:  4
# Enter second Number:  7
# Enter third Number:  6
# 4 6 7

# %% [markdown]
# # Part-2

# %%
#1 positive, negative or zero
num = int(input("Enter a Number: "))
if num>0:
    print("Positive")
elif num<0:
    print("Negative")
else:
    print("Zero")
# Out:
# Enter a Number:  -9
# Negative

# %%
#2 Movie Theater Entery
age = int(input("Enter Age: "))
if age>=18:
    print("Entery Allowed")
else:
    print("Enter is Not Allowed")
# Out:
# Enter Age:  12
# Enter is Not Allowed

# %%
#3 Number is divisible by 2
num = int(input("Enter the Number: "))
if num%2==0:
    print("Number is Divisible by 2")
else:
    print("Number is Not Divisible by 2")
# Out:
# Enter the Number:  9
# Number is Not Divisible by 2

# %%
#4 Compare Two number and find greater number
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
if a>b:
    print(a)
else:
    print(b)
# Out:
# Enter first number:  23
# Enter second number:  2
# 23

# %%
#5 uppercase or lowercase
character = input("Enter Character: ")
if character.isupper():
    print("Character is in Uppercase")
else:
    print("Character is in Lowercase")
# Out:
# Enter Character:  k
# Character is in Lowercase

# %%
#6 Leap year or not
year = int(input("Enter Year: "))
if (year%4==0 and year%100!=0) or (year%400==0):
    print("Leap Year")
else:
    print("Not a Leap Year")
# Out:
# Enter Year:  2020
# Leap Year

# %%
#7 Display "Morning","Afternoon", "Evening"
time = int(input("Enter Time in between (0-23) Hour: "))
if time<12:
    print("Morning")
elif 12<time>5:
    print("Afternoon")
else:
    print("Evening")
# Out:
# Enter Time in between (0-23) Hour:  15
# Afternoon

# %%
#8 Check whether student passed with distinction
per = int(input("Enter Student Percentage: "))
if per>=75:
    print("Distinction")
elif per>=35:
    print("Pass")
else:
    print("Failed")
# Out:
# Enter Student Percentage:  52
# Pass

# %%
#9 largest number among three
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))
if a>=b and a>=c:
    print(a)
elif b>=a and b>=c:
    print(b)
else:
    print(c)
# Out:
# Enter first number:  12
# Enter second number:  16
# Enter third number:  40
# 40

# %%
#10 calculate electric Bill
units = int(input("Enter Total Units Consumed: "))
if units<100:
    bill = 2*units
elif units<300:
    bill = 4*units
else:
    bill = 6*units
print("Bill = ",bill)
# Out:
# Enter Total Units Consumed:  123
# Bill =  492

# %%
#11 Type of Triangle
a = int(input("Enter side 1: "))
b = int(input("Enter side 2: "))
c = int(input("Enter side 3: "))
if a==b==c:
    print("Equilateral Triangle")
elif a==b or b==c or a==c:
    print("Isosceles Triangle")
else:
    print("Scalene")
# Out:
# Enter side 1:  2
# Enter side 2:  3
# Enter side 3:  6
# Scalene

# %%
#12 Calculate Bonus
salary = int(input("Enter the Salary: "))
if salary>50000:
    bonus = salary*20/100
elif 30000<salary>50000:
    bonus = salary*10/100
else:
    bonus = salary*5/100
print("Total Bonus= ",bonus)
# Out:
# Enter the Salary:  45000
# Total Bonus=  2250.0

# %%
#13 Check credential using username and password
username = input("Enter username: ")
password = input("Enter password: ")
if username == "admin" and password == "123":
    print("Login Successful")
else:
    print("Login Failed")
# Out:
# Enter username:  admin
# Enter password:  29
# Login Failed

# %%
#14 multiple of 3 and 5
num = int(input("Enter Number: "))
if num%3==0 and num%5==0:
    print("Number is multiple of both")
elif num%3==0:
    print("Number is multiple of 3")
elif num%5==0:
    print("Number is multiple of 5")
else:
    print("None")
# Out:
# Enter Number:  9
# Number is multiple of 3

# %%
#15 Age of Person
age = int(input("Enter the Age of Person: "))
if age<12:
    print("Child")
elif age<19:
    print("Teenager")
elif age<59:
    print("Adult")
else:
    print("Senior Citizen")
# Out:
# Enter the Age of Person:  13
# Teenager

# %%
#16 Calculate ticket price
age = int(input("Enter Age: "))
if age<5:
    print("Free")
elif age<=18:
    print(100)
elif age<=60:
    print(200)
else:
    print(150)
# Out:
# Enter Age:  21
# 200

# %%
#17 Create simple ATM system
Balance = 5000
print("1. Check Balance")
print("2. Withdraw money")
print("3. Deposit money")
choice = int(input("Enter Choice: "))
if choice == 1:
    print("Balance: ",Balance)
elif choice == 2:
    amount = int(input("Enter Amount: "))
    Balance = Balance - amount
    print("Balance: ",Balance)
elif choice == 3:
    amount = int(input("Enter Amount: "))
    Balance = Balance + amount
    print("Balance: ",Balance)
else:
    print("Invalid Option")
# Out:
# 1. Check Balance
# 2. Withdraw money
# 3. Deposit money
# Enter Choice:  3
# Enter Amount:  1500
# Balance:  6500

# %%
#18 Calculate Income Tax
income = int(input("Enter Yearly Income: "))
if income<250000:
    tax = 0
elif income<500000:
    tax = income*5/100
elif income<1000000:
    tax = income*20/100
else:
    tax = income*30/100
print("Total Tax: ",tax)
# Out:
# Enter Yearly Income:  395000
# Total Tax:  19750.0

# %%
#19 Determine the type of roots in quadratic equation
a = int(input())
b = int(input())
c = int(input())
d = b*b - 4*a*c
if d>0:
    print("Real and Different")
elif d==0:
    print("Real and Equal")
else:
    print("Imaginary")
# Out:
#  5
#  10
#  2
# Real and Different

# %%
#20  Mini Calculator
a = int(input("Enter first Number: "))
b = int(input("Enter Second Number: "))
oper = input("Enter + - * /")
if oper == "+":
    print(a+b)
elif oper == "-":
    print(a-b)
elif oper == "*":
    print(a*b)
elif oper == "/":
    print(a/b)
else:
    print("Invalid Operation")
# Out:
# Enter first Number:  25
# Enter Second Number:  5
# Enter + - * / +
# 30

# %%
#21 Check Whether three angles can form a valid triangle
angle1 = int(input("Enter first Angle: "))
angle2 = int(input("Enter second Angle: "))
angle3 = int(input("Enter third Angle: "))
if angle1 + angle2 + angle3 == 180:
    print("Valid Triangle")
else:
    print("Invalid Triangle")
# Out:
# Enter first Angle:  45
# Enter second Angle:  45
# Enter third Angle:  30
# Invalid Triangle

# %%
# 22 Season by month
month = int(input("Enter Month: "))
if month in [12, 1, 2]:
    print("Winter")
elif month in [3, 4, 5]:
    print("Summer")
elif month in [6, 7, 8]:
    print("Monsoon")
elif month in [9, 10, 11]:
    print("Autum")
else:
    print("Invalid Month")
# Out:
# Enter Month:  12
# Winter

# %%
# 23 Shopping Discount
amount = int(input("Enter Purchase amount: "))
if amount>5000:
    discount = number * 30/100
elif amount >= 2000:
    discount = amount * 20/100
else:
    discount = amount * 10/100
print("Discount = ",discount)
print("Final Amount = ", amount-discount)
# Out:
# Enter Purchase amount:  2500
# Discount =  500.0
# Final Amount =  2000.0

# %%
# 24 Employee Rating
score = int(input("Enter performance score: "))
if score >= 90:
    print("Excellent")
elif score >= 70:
    print("Good")
elif score >= 50:
    print("Average")
else:
    print("Poor")
# Out:
# Enter performance score:  65
# Average
