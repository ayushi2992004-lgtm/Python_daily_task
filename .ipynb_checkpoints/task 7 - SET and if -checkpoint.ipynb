# %%
# 1 Create a set with numbers {1, 2, 3, 2, 4, 1} and print it.
set = {1, 2, 3, 2, 4, 1}
print(set)
# Out:
# {1, 2, 3, 4}

# %%
# 2 Create an empty set using correct syntax and add 3 numbers using add().
s = set()
s.add(10)
s.add(20)
s.add(30)
print(s)
# Out:
# {10, 20, 30}

# %%
# 3 Given s = {10, 20, 30}, add multiple elements [40, 50, 60] using update().
set = {10, 20, 30}
set.update([40, 50, 60])
print(set)
# Out:
# {40, 10, 50, 20, 60, 30}

# %%
# 4 Remove element 20 from set s = {10, 20, 30, 40} using remove() and discard(). Show difference.
set = {10, 20, 30, 40}
set.remove(20)
print(set)

set.discard(50)
print(set)
# Out:
# {40, 10, 30}
# {40, 10, 30}

# %%
# 5 Create two sets A = {1, 2, 3, 4} and B = {3, 4, 5, 6}. Print union, intersection, and difference.
A = {1, 2, 3, 4}
B = {3, 4, 5, 6}
print(A.union(B))
print(A.intersection(B))
print(A.difference(B))
# Out:
# {1, 2, 3, 4, 5, 6}
# {3, 4}
# {1, 2}

# %%
# 6 Check if 25 is present in set s = {10, 20, 30, 40} using in keyword.
set = {10, 20, 30, 40}
print(25 in set)
# Out:
# False

# %%
# 7 Create a set from the list [1, 2, 2, 3, 4, 4, 5] and print its length.
list = [1, 2, 2, 3, 4, 4, 5]
s = set(list)
print(s)
print(len(s))
# Out:
# {1, 2, 3, 4, 5}
# 5

# %%
# 8 Take 5 numbers as input from user, store them in a set, and print unique numbers only.
num1 = int(input())
num2 = int(input())
num3 = int(input())
num4 = int(input())
num5 = int(input())
s = {num1, num2, num3, num4, num5}
print(s)
# Out:
#  1
#  2
#  2
#  9
#  5
# {1, 2, 5, 9}

# %%
# 9 Given two sets A = {1, 2, 3} and B = {3, 4, 5}, print elements that are in A but not in B.
A = {1,2,3}
B = {3,4,5}
print(A.difference(B))
# Out:
# {1, 2}

# %%
# 10 Create a set and try to add a list [1,2,3] inside it.
set = {10,20}
set.add([30,40,50])
print(set)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 3
#       1 # 10
#       2 set = {10,20}
# ----> 3 set.add([30,40,50])
#       4 print(set)
#
# TypeError: unhashable type: 'list'

# %%
# 11 Take age as input. If age >= 18, print "You are eligible to vote".
age = int(input("Enter the age: "))
if age>=18:
    print("You are eligible to vote")
# Out:
# Enter the age:  19
# You are eligible to vote

# %%
# 12 Take a number and check if it is positive, negative, or zero using if-elif-else.
num = int(input("Enter the number: "))
if num>0:
    print("Number is positive")
elif num<0:
    print("Number is Negative")
else:
    print("Number is zero")
# Out:
# Enter the number:  -9
# Number is Negative

# %%
# 13 Take two numbers and print the larger one using if-else.
A = int(input())
B = int(input())
if A>B:
    print(A)
else:
    print(B)
# Out:
#  45
#  25
# 45

# %%
# 14 Take a character and check if it is a vowel (a, e, i, o, u) using if statement.
character = input("Enter the character: ")
if character in "aeiouAEIOU":
    print("Vowel")
else:
    print("Not Vowel")
# Out:
# Enter the character:  i
# Vowel

# %%
# 15 Take marks and print grade: ≥90 → A, ≥80 → B, ≥70 → C, else → Fail.
Marks = int(input("Enter Marks obtained: "))
if Marks>=90:
    print("A Grade")
elif Marks>=80:
    print("B Grade")
elif Marks>=70:
    print("C Grade")
else:
    print("Fail")
# Out:
# Enter Marks obtained:  82
# B Grade

# %%
# 16 Take three numbers and print the largest one using if-elif-else.
a = int(input())
b = int(input())
c = int(input())
if a>=b and a>c:
    print(a)
elif b>=a and b>c:
    print(b)
else: 
    print(c)
# Out:
#  12
#  32
#  0
# 32

# %%
# 17 Take a number and check if it is even and greater than 50.
num = int(input("Enter the Number: "))
if num%2==0 and num>50:
    print("Yes")
else:
    print("No")
# Out:
# Enter the Number:  52
# Yes

# %%
# 18 Take username and password. If username == "admin" and password == "1234", print "Login Successful", else "Login Failed".
username = input("Enter usename: ")
password = input("Enter password: ")
if username=="admin" and password=="1234":
    print("Login Successful")
else:
    print("Login Failed")
# Out:
# Enter usename:  admin
# Enter password:  1234
# Login Successful

# %%
# 19 Take a year as input and check if it is a leap year (divisible by 4 but not 100, or divisible by 400).
year = int(input("Enter the year: "))
if (year%4==0 and year%100!=0) or (year%400==0):
    print("Leap Year")
else:
    print("Not a Leap Year")
# Out:
# Enter the year:  2026
# Not a Leap Year

# %%
# 20 Take three sides of a triangle and check if they can form a valid triangle (sum of any two sides > third side
a = int(input())
b = int(input())
c = int(input())
if a+b>c and a+c>b and b+c>a:
    print("Valied Triangle")
else:
    print("Invalied Triangle")
# Out:
#  5
#  5
#  20
# Invalied Triangle

# %%
# 21 Take three numbers as input from the user. Print the largest number and also check whether all three numbers are equal or not.
a = int(input())
b = int(input())
c = int(input())
if a>=b and a>=c:
    print("Largest:",a)
elif b>=a and b>=c:
    print("Largest:",b)
else:
    print("Largest:",c)
if a==b==c:
    print("All are Equal")
else:
    print("Not Equal")
# Out:
#  42
#  26
#  20
# Largest: 42
# Not Equal

# %%
# 22 Take a year as input. Check if it is a leap year or not. (A year is leap if divisible by 4, but not by 100, unless also divisible by 400)
year = int(input("Enter the Year: "))
if (year%4==0 and year%100!=0) or (year%400==0):
    print("Leap Year")
else:
    print("Not a Leap Year")
# Out:
# Enter the Year:  2020
# Leap Year

# %%
# 23 Take three sides of a triangle as input. Check if they can form a valid triangle (sum of any two sides must be greater than the third side). If valid, also print the type (Equilateral, Isosceles, or Scalene).
a = int(input())
b = int(input())
c = int(input())
if a+b>c and a+c>b and c+b>a:
    print("Valied Triangle")
    if a==b==c:
        print("Equilateral Triangle")
    elif a==b or b==c or a==c:
        print("Isosceles")
    else:
        print("Scalene")
else:
    print("Invalied Triangle")
# Out:
#  6
#  5
#  2
# Valied Triangle
# Scalene

# %%
# 24 Take a student's marks in 5 subjects. Calculate percentage and print grade according to these rules:
m1 = int(input())
m2 = int(input())
m3 = int(input())
m4 = int(input())
m5 = int(input())
total = m1+m2+m3+m4+m5
per = total/5
print("Percentage = ",per)
if per>=90:
    print("A+")
elif per>=80:
    print("A")
elif per>=70:
    print("B")
elif per>=60:
    print("c")
else:
    print("Fail")
if per>=75:
    print("Passed with Distinction")
# Out:
#  98
#  92
#  91
#  54
#  65
# Percentage =  80.0
# A
# Passed with Distinction

# %%
# 25 Take username, password, and age as input.
username = input("Enter Username: ")
password = input("Enter Password: ")
age = int(input("Enter Age: "))
if username=="admin" and password=="123" and age>=18:
    print("Login Successful")
elif age<18:
    print("You are too young to login")
else:
    print("Invalied Credential")
# Out:
# Enter Username:  ayu
# Enter Password:  32
# Enter Age:  12
# You are too young to login
